# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.drop("sl_no", axis=1, inplace=True)

# %%
dataset.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status    salary
# 0     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
# Qn: 1)Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
dataset.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# Methods to Handle NaN Values
#
# 1) Can drop the entire column
# 2) Can use central tendency
# 3) Can replace specific value

# %%
dataset[dataset["salary"].isnull()]
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
# for multiple column null values

#df = pd.DataFrame(dataset)
#rows_with_multiple_missing_values = df[df[['Score', 'Age']].isna().all(axis=1)]
#rows_with_missing_values

# %%
dataset.fillna(0, inplace=True)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isna().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
# Qn2: How many of them are not placed?

# %%
dataset[dataset["status"]=="Not Placed"].shape[0]
# Out:
# 67

# %%
#Answer: 67 students are not placed out of 215

# %%
# Qn 3) Find the reason for non placement from the dataset?

# %%
dataset[dataset["status"]=="Not Placed"]
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
#Answer: Majority of the "Not Placed" students have "NO WORK EXPERIENCE".

# %%
#Qn:4) What kind of relation between salary and mba_p

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
from Univariate import QuanQual

# %%
Quan, Qual= QuanQual.QuanQual(dataset)
# Out:
# Quan= ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# Qual= ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
dataset[Quan].corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#Ans: The relationship or correlation between MBA mark and salary is positive relation at the rate of 13%.

# %%
#Qn:5)Which specialization is getting minimum salary?

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
dataset["specialisation"].value_counts()
# Out:
# specialisation
# Mkt&Fin    120
# Mkt&HR      95
# Name: count, dtype: int64

# %%
sns.barplot(dataset, x="specialisation", y="salary")
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
hr = dataset[dataset["specialisation"]=="Mkt&HR"] ["salary"].sum()
Fin = dataset[dataset["specialisation"]=="Mkt&Fin"] ["salary"].sum()

# %%
print("Sum of HR dep Salary:", hr)
print("Sum of Finance Salary:",Fin)
# Out:
# Sum of HR dep Salary: 14330000.0
# Sum of Finance Salary: 28391000.0

# %%
hr = dataset[dataset["specialisation"]=="Mkt&HR"] ["salary"]
Fin = dataset[dataset["specialisation"]=="Mkt&Fin"] ["salary"]
print("HR min salary:", hr.min())
print("Finance min salary:", Fin.min())
print("HR max salary:", hr.max())
print("Finance max salary:",Fin.max())
# Out:
# HR min salary: 0.0
# Finance min salary: 0.0
# HR max salary: 450000.0
# Finance max salary: 940000.0

# %%
# Ans: Based on Min & Max, both depart is getting min salary of 2,00,000
# But Based on sum of salaries getting by 2 specialisation, HR department is getting lower salary compared to Finance department

# %%
#Qn 6)How many of them getting above 500000 salary?

# %%
dataset[dataset["salary"]>=500000].shape[0]
# Out:
# 6

# %%
#Answer: 6 students getting salary above 500000

# %%
#Qn: 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import f_oneway
f_oneway(dataset["etest_p"], dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#Null(H0) = There is no significant relationship between entrance test & MBA test marks
#Alternative(H1) = There is significant relationship between entrance test & MBA test marks
# Condition:  signifance level 5%

#Reject NULL hypothesis if p>5%

# %%
# Ans: pvalue=4.672547689133573e-21 which is lesser than 5%. so accepting "NULL Hypothesis"

# %%
# QN: 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.
#(Makedecision using Hypothesis Testing)

# %%
#Null Hypothesis: There is no similary between degree_t(Sci&Tech) and specialisation(Mkt&HR) salary
#Alternative Hypothesis: There is similary between degree_t(Sci&Tech) and specialisation(Mkt&HR) salary

#condition: Reject Null hypothesis id p>0.05

# %%
from scipy.stats import ttest_ind
degree=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
spec=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]
ttest_ind(degree, spec)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %%
#Ans: pvalue=0.0078. Since p<0.05, reject null hypothesis and accept alternative hypothesis

# %%
#Qn:9)Convert the normal distribution to standard normal distribution for salary column

# %%
#normal distrubtion:

import seaborn as sns
sns.histplot(dataset["salary"], kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
#Converting the normal distribution to std normal distribution
#Formula: z_score = j-mean/std

# %%
mean=dataset["salary"].mean()
std=dataset["salary"].std()
print("Mean:{}, Std deviation:{}".format(mean, std))
values= [i for i in dataset["salary"]]
z_score= [((j-mean)/std) for j in values]
sns.distplot(z_score, kde=True)
# Out:
# Mean:198702.32558139536, Std deviation:154780.92671560106
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13396\3760920506.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score, kde=True)
# <Axes: ylabel='Density'>

# %%
#10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
def pdf(dataset, startrange, endrange):
    import seaborn as sns
    from matplotlib import pyplot
    from scipy.stats import norm
    ax=sns.histplot(dataset, kde=True)
    pyplot.axvline(startrange, color="Red")
    pyplot.axvline(endrange,  color="Red")
    mean=dataset.mean()
    std=dataset.std()
    print("Mean:{} and Std Deviation:{}" .format(mean, std))
    dist=norm(mean, std)
    values = [value for value in range(startrange, endrange)]
    probablities = [dist.pdf(value) for value in values]
    prob=sum(probablities)
    print("The area between the range {}, {} is {}" .format(startrange, endrange, prob))
    return prob

# %%
pdf(dataset["salary"], 700000, 900000)
# Out:
# Mean:198702.32558139536 and Std Deviation:154780.92671560106
# The area between the range 700000, 900000 is 0.0005973310593974901
# 0.0005973310593974901

# %%
#11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.
#(Make decision using Hypothesis Testing)

# %%
#Null hypothesis: There is no similarity between degree_t(Sci&Tech) with respect to etest_p and mba_p
#Alternative hypothesis: There is similarity between degree_t(Sci&Tech) with respect to etest_p and mba_p

#condition: Reject null hypothesis if p<0.05

# %%
from scipy.stats import ttest_rel
degree_t=dataset[dataset["degree_t"] =="Sci&Tech"]['etest_p']
degree_t1=dataset[dataset["degree_t"] =="Sci&Tech"]["mba_p"]
ttest_rel(degree_t, degree_t1)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %%
#Answer: pvalue=5.517920600505392e-06. So p>0.05, we are rejecting alternative and accepting null hypothesis

# %%
#12)Which parameter is highly correlated with salary?

# %%
dataset[Quan].corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#Ans: Based on the above table, the correlation between SSC pass mark and Salary is high at the rate of 53%

# %%
#13)plot any useful graph and explain it.

# %%
from matplotlib import pyplot
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
#Explanation: pairplot from seaborn helps us to view the linear relationship between various variables in the dataset.

# %%
sns.histplot(dataset["hsc_p"], kde=True)
# Out:
# <Axes: xlabel='hsc_p', ylabel='Count'>

# %%
#Histogram explanation: Histogram is the visual represntation of the density. It helps us to see how many students scored particular marks

# %%
import matplotlib.pyplot as plt
plt.bar(dataset["specialisation"], dataset["hsc_p"], color='skyblue')
plt.title('Bar Chart')
plt.xlabel("specialisation")
plt.ylabel("hsc_p")
plt.show()

# %%
#Barchart explanation: This barchart explains which specialisation scored highest score in HSC.

# %%
import matplotlib.pyplot as plt
plt.bar(dataset["specialisation"], dataset["salary"], color='skyblue')
plt.title('Bar Chart')
plt.xlabel("specialisation")
plt.ylabel("salary")
plt.show()

# %%
#Barchart explanation: This barchart explains which specialisation is getting highest salary.

# %%
sns.barplot(dataset, x="specialisation", y="salary")
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
sns.barplot(data=dataset, x="specialisation", y="salary", hue="gender")
plt.show()

# %%
dataset.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.bar(dataset["gender"], dataset["salary"], color='skyBlue')
plt.title('Bar Chart')
plt.xlabel("gender")
plt.ylabel("salary")
plt.show()

# %%
sns.jointplot(dataset, x="ssc_p", y="salary")

# %%
sns.jointplot(dataset, x="ssc_p", y="salary", kind='hex')

# %%
sns.pairplot(dataset, hue="status")

# %%
#To plot the graph between Qual & Quan

# %%
sns.swarmplot(dataset, x="hsc_b", y="hsc_p")
# Out:
# <Axes: xlabel='hsc_b', ylabel='hsc_p'>

# %%
sns.stripplot(dataset, x="hsc_b", y="hsc_p")
# Out:
# <Axes: xlabel='hsc_b', ylabel='hsc_p'>

# %%
sns.violinplot(dataset, x="ssc_b", y="salary", hue="gender")
# Out:
# <Axes: xlabel='ssc_b', ylabel='salary'>

# %%
sns.boxplot(dataset, x="ssc_b", y="ssc_p")
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.countplot(dataset, x="ssc_b", hue="gender")
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %%
sns.catplot(dataset["ssc_p"])
